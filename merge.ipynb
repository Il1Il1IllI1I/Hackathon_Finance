# %%
import pandas as pd

# %%
a = pd.read_csv('datasets/ks200.csv')

# %%
b = pd.read_csv('tech.csv')

# %%
c = pd.concat([a,b], axis=1)

# %%
d = pd.concat([a,b], axis=1, join='inner')

# %%
d.to_csv("merge.csv")

# %%
e = pd.merge(a, b)

# %%
e.to_csv("merge.csv")

# %%
f = pd.merge(a,b, how='outer', on = 'Date')

# %%
f
# Out:
#             Date forward_stage     WTI  USDKRW    VIX          1    2       3  \
# 0     2011-04-01          down  107.94  1099.2  17.40  1686110.4  3.0  123.11
# 1     2011-04-04          down  108.47  1085.2  17.50  1686110.4  3.0  123.11
# 2     2011-04-05          down  108.34  1086.5  17.25  1686110.4  3.0  123.11
# 3     2011-04-06          down  108.83  1087.2  16.90  1686110.4  3.0  123.11
# 4     2011-04-07       neutral  110.30  1083.3  17.11  1686110.4  3.0  123.11
# ...          ...           ...     ...     ...    ...        ...  ...     ...
# 3015  2023-01-02           NaN     NaN     NaN    NaN        NaN  NaN     NaN
# 3016  2023-01-16           NaN     NaN     NaN    NaN        NaN  NaN     NaN
# 3017  2023-02-20           NaN     NaN     NaN    NaN        NaN  NaN     NaN
# 3018  2023-04-07           NaN     NaN     NaN    NaN        NaN  NaN     NaN
# 3019  2023-06-19           NaN     NaN     NaN    NaN        NaN  NaN     NaN
#
# ...
